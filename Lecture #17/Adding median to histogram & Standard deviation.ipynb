# %%
import numpy as np
import matplotlib.pyplot as plt

import statistics
 
# Data in numpy array
d = np.array([189, 185, 195, 149, 189, 147, 154, 
          174, 169, 195, 159, 192, 155, 191,134,144,137,139,
          153, 157, 140, 144, 172, 157, 181, 
          182, 166, 167,140,130,150,190,171,189,142,153,159,161,169,165,133,188])


medianline = [x/2 for x in d]
print(medianline)

plt.hist(d, bins=50 , color='c' , edgecolor = 'k')

m  = statistics.mean(d)

sd =  statistics.stdev(d)

plt.axvline(m, color= 'k' , linestyle="dashed")

plt.axvline(m+sd, color= 'y' , linestyle="dashed")
plt.axvline(m-sd, color= 'y' , linestyle="dashed")

plt.show()
# Out:
# [94.5, 92.5, 97.5, 74.5, 94.5, 73.5, 77.0, 87.0, 84.5, 97.5, 79.5, 96.0, 77.5, 95.5, 67.0, 72.0, 68.5, 69.5, 76.5, 78.5, 70.0, 72.0, 86.0, 78.5, 90.5, 91.0, 83.0, 83.5, 70.0, 65.0, 75.0, 95.0, 85.5, 94.5, 71.0, 76.5, 79.5, 80.5, 84.5, 82.5, 66.5, 94.0]
