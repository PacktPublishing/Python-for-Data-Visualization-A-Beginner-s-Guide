# %%
import numpy as np
import matplotlib.pyplot as plt
 
# Data in numpy array
exp_data = np.array([189, 185, 195, 149, 189, 147, 154, 
          174, 169, 195, 159, 192, 155, 191,134,144,137,139,
          153, 157, 140, 144, 172, 157, 181, 
          182, 166, 167,140,130,150,190,171,189,142,153,159,161,169,165,133,188])
 
# Plot the distribution of numpy data
plt.hist(exp_data, bins = , align='left', color='b', edgecolor='red',linewidth=1)
 
# Add axis labels
# plt.xlabel("Student Ages in cm")
# plt.xticks(range(0,20,2))
# plt.yticks(range(0,20,1))
# plt.ylabel("Students Quantity")
# plt.title("Example of Histogram Plot")
 
plt.show()
