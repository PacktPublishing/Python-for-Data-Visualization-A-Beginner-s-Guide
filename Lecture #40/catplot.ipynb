# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the example tips dataset
tips = sns.load_dataset("tips")

#Create a categorical scatter plot of tip by day and sex
sns.catplot(data=tips, x="day", y="tip", hue="sex", kind="swarm")

# Set the title and axis labels
plt.title("Tip by Day and Sex")
plt.xlabel("Day of the Week")
plt.ylabel("Tip")

# Show the plot
plt.show()
# Out:
# C:\Users\Sohai\anaconda4\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
