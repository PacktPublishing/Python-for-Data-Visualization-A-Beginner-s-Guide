# %%
#wedgeprops = { 'linewidth' : '', 'edgecolor' : '' }


import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]



plt.pie(y, labels = mylabels  , wedgeprops = { 'linewidth' : '1', 'edgecolor' : 'white' })
plt.show()

# %%
## Create a set of colors
#colors = ['#4F6272', '#B7C3F3', '#DD7596', '#8EB897']


import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

colors = ['#4F6272', '#B7C3F3', '#DD7596', '#8EB897']



plt.pie(y, labels = mylabels  , wedgeprops = { 'linewidth' : '1', 'edgecolor' : 'white' }  , colors = colors)
plt.show()

# %%
## Create a set of colors
#colors = ['#4F6272', '#B7C3F3', '#DD7596', '#8EB897']


import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

colors = ['#4F6272', '#B7C3F3', '#DD7596', '#8EB897']



plt.pie(y, labels = mylabels  , wedgeprops = { 'linewidth' : '1', 'edgecolor' : 'white' }  , colors = colors , shadow = 'true')
plt.show()
